# %% [markdown]
# <div class="report">
#
# # Лабораторная работа №6. Сегментация текста
# **Вариант:** 23 (английские заглавные буквы)
#
# ---
#
# ## 1. Исходные данные
# **Фраза:** "I LOVE YOU"
# **Параметры генерации:**
# - Шрифт: Times New Roman
# - Кегль: 52 pt
# - Формат изображения: Монохромный BMP
# - Размер исходного файла: 869×109 px
#
# <div class="img-box">
#     <img src="text.bmp" width="500">
#     <p>Рис. 1. Исходное монохромное изображение</p>
# </div>
#
# ---
#
# ## 2. Профили текста
# <div class="img-box">
#     <img src="text_profiles.png" width="700">
#     <p>Рис. 2. Профили текста: вертикальный (сверху) и горизонтальный (снизу)</p>
# </div>
#
# ---
#
# ## 3. Результаты сегментации
# **Найденные границы символов:**
# `[(8, 51), (96, 182), (191, 290), (297, 404), (409, 495), (539, 645), (653, 751), (758, 866)]
# `
#
# <div class="img-box">
#     <img src="segmented_text.png" width="500">
#     <p>Рис. 3. Результат сегментации с bounding boxes </p>
# </div>
#
# ---
#
# ## 4. Профили символов алфавита
# **Примеры характеристик для букв I, L, O:**
#
# <div class="img-box">
#     <div style="display: flex; gap: 30px; flex-wrap: wrap">
#         <div>
#             <img src="profile_I.png" width="300">
#             <p>Рис. 4.1. Профили буквы I</p>
#         </div>
#         <div>
#             <img src="profile_L.png" width="300">
#             <p>Рис. 4.2. Профили буквы L</p>
#         </div>
#         <div>
#             <img src="profile_O.png" width="300">
#             <p>Рис. 4.3. Профили буквы O</p>
#         </div>
#     </div>
# </div>
