# %% [markdown]
# # Лабораторная работа №10. Обработка голоса
#
# ## Результаты анализа
#
# ### 1. Звук «А» (`А.wav`)
# - **Спектрограмма:**
#   ![Спектрограмма](А.wav_spectrogram.png)
# - **Минимальная частота:** 58.6 Гц
# - **Максимальная частота:** 773.4 Гц
# - **Основной тон:** 562.5 Гц
# - **Форманты:** [140.6 Гц, 562.5 Гц, 714.8 Гц]
#
# ### 2. Звук «И» (`И.wav`)
# - **Спектрограмма:**
#   ![Спектрограмма](И.wav_spectrogram.png)
# - **Минимальная частота:** 105.5 Гц
# - **Максимальная частота:** 6515.6 Гц
# - **Основной тон:** 234.4 Гц
# - **Форманты:** [234.4 Гц, 363.3 Гц, 3644.5 Гц]
#
# ### 3. Лай (`barking.wav`)
# - **Спектрограмма:**
#   ![Спектрограмма](barking.wav_spectrogram.png)
# - **Минимальная частота:** 96.9 Гц
# - **Максимальная частота:** 2099.5 Гц
# - **Основной тон:** 441.4 Гц
# - **Форманты:** [441.4 Гц, 742.9 Гц, 1292.0 Гц]
