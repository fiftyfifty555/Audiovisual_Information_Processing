# %% [markdown]
# # Лабораторная работа №8. Контрастирование и текстурный анализ (Вариант 3)
#
# ---
#
# ## Цель работы
# 1. Построение матрицы NGLDM (Neighborhood Gray-Level Difference Matrix) для анализа текстуры.
# 2. Расчет признаков CNG (Coarseness) и CON (Contrast).
# 3. Применение выравнивания гистограммы для контрастирования.
# 4. Сравнение текстурных признаков до и после преобразования.
#
# ---
#
#
# - **Изображения:** `input.bmp`, `LAB2_1.bmp`, `LAB2_3.bmp`.
#
# ---
#
# ## Результаты
#
# ### 1. Исходные и контрастированные изображения
# **Метод преобразования:** Выравнивание гистограммы.
# **Параметры:**
# - Расстояние соседства: `d=1`.
#
# | файл |Изображение |
# |------------------|------------------------------- |
# | `input.bmp`       |  ![Контраст](input_analysis.png) |
# | `LAB2_1.bmp`      |  ![Контраст](LAB2_1_analysis.png) |
# | `LAB2_3.bmp`      |![Контраст](LAB2_3_analysis.png)  |
#
# ---
#
#
#
# **Значения признаков:**
# | Изображение       | CNG (исходное) | CON (исходное) | CNG (контраст) | CON (контраст) | Δ CNG | Δ CON |
# |-------------------|----------------|----------------|----------------|----------------|-------|-------|
# | `input.bmp`       | 0.16          | 127.68         | 0.13           | 197.72        | -0.03 | +70.04 |
# | `LAB2_1.bmp`      | 0.25           | 191.24    | 0.05          | 2038.06       | -0.20 | +1846.82|
# | `LAB2_3.bmp`      | 0.12           | 278.52         | 0.11          | 344.90         | --0.01 | +66.38 |
